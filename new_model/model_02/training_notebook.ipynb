# %%
#import libraries
import numpy as np
from ase.io import read, write
from ase import Atoms
import torch
import yaml
import json
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
os.makedirs('img_res', exist_ok=True) #creates a folder to store the loss graphs
os.makedirs('test_res', exist_ok=True) #creates a folder to store the files of the testing of the model
import functions as f #import functions used to plot

# %%
#I found a warning regarding the key names for energy and forces, the label changes from 'energy' to 'REF_energy'
input_file = "251030_training_data_lt_2eV.xyz"
output_file = "251030_training_data_lt_2eV_fixed.xyz"

with open(input_file, "r") as f:
    lines = f.readlines()

new_lines = []
for line in lines:
    # Fix energy key in header lines
    if "energy=" in line:
        line = line.replace("energy=", "REF_energy=")
    # Fix forces key in Properties line
    if "Properties=" in line and "forces:R:3" in line:
        line = line.replace("forces:R:3", "REF_forces:R:3")
    new_lines.append(line)

# Write the fixed file
with open(output_file, "w") as f:
    f.writelines(new_lines)

# %%
read_data = read('251030_training_data_lt_2eV_fixed.xyz', index=':')
db_data = [(a.info['REF_energy']) for a in read_data]
df = pd.DataFrame(db_data, columns=['REF_energy'])
df = df[3:]
plt.hist(df)
# Out:
# (array([  1.,   0.,   0.,   2.,   0.,   0.,   0.,  99., 231., 300.]),
#  array([-1058.06881603,  -950.68316777,  -843.29751952,  -735.91187126,
#          -628.52622301,  -521.14057475,  -413.75492649,  -306.36927824,
#          -198.98362998,   -91.59798173,    15.78766653]),
#  <BarContainer object of 10 artists>)

# %%
#importing the full data (this is in case I have like the whole data in one file)
db = read('251030_training_data_lt_2eV_fixed.xyz', ':')

# %%
#splitting the data into the training and test sets
write('train_01.xyz', db[:520])
write('test_01.xyz', db[520:])

# %%
#setting the model name based on model number and epochs
device = 'cpu'
''' model_num:
    1 -> this indicates the model using 250 training data
    2 -> this indicates the model using 520 training data which is 80% of the data set
    3,4 -> this indicates the model using different values of learning rate 0.005, 0.0001 '''
model_id = 'scaleshift_lr0.0001_highEweighted'
#model_id = 'mace_lr0.0001'
#model_num = 4
''' num_epochs:
    sets the number of epochs used for running the trainig'''
num_epoch = 25
''' batch_size:
    sets the batch size for training'''
batch_size = 25
''' model_name:
    generates the name of the model based on the number of epochs and the model number using the 'model_num' variable '''
model_name = f'model_{model_id}_{num_epoch}epochs_{batch_size}batch'
model_name
# Out:
# 'model_scaleshift_lr0.0001_highEweighted_25epochs_25batch'

# %%
#this writes the yml file
config = {
    "model": "ScaleShiftMACE",
    #"model": "MACE",
    "num_channels": 32,
    "max_L": 0,
    "r_max": 4.0,
    "name": model_name,
    "train_file": f"train_01.xyz",
    "valid_fraction": 0.01,
    "test_file": f"test_01.xyz",
    "energy_key": "REF_energy",
    "forces_key": "REF_forces",
    "batch_size": batch_size,
    "max_num_epochs": num_epoch,
    "optimizer" : "adam",
    "lr":0.0001,
    "device": device,
    "seed": 123,
    'config_type_weights': {'highE': 0.2}
}
with open("config_new_model.yml", "w") as f:
    yaml.dump(config, f, sort_keys=False)

# %%
#Perform training
import warnings
warnings.filterwarnings('ignore')
from mace.cli.run_train import main as mace_run_train_main
import sys
import logging

#defining the training function
def train_mace(config_file_path):
    logging.getLogger().handlers.clear()
    sys.argv = ['program', '--config', config_file_path]
    mace_run_train_main()

#calling the function
train_mace('config_new_model.yml') # use the name of the config file that was created
# Out:
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2025-11-04 21:01:40.119 INFO: ===========VERIFYING SETTINGS===========
# 2025-11-04 21:01:40.119 INFO: MACE version: 0.3.14
# 2025-11-04 21:01:40.120 INFO: Using CPU
# 2025-11-04 21:01:40.195 INFO: ===========LOADING INPUT DATA===========
# 2025-11-04 21:01:40.196 INFO: Using heads: ['Default']
# 2025-11-04 21:01:40.197 INFO: Using the key specifications to parse data:
# 2025-11-04 21:01:40.197 INFO: Default: KeySpecification(info_keys={'energy': 'REF_energy', 'stress': 'REF_stress', 'virials': 'REF_virials', 'dipole': 'dipole', 'head': 'head', 'elec_temp': 'elec_temp', 'total_charge': 'total_charge', 'polarizability': 'polarizability', 'total_spin': 'total_spin'}, arrays_keys={'forces': 'REF_forces', 'charges': 'REF_charges'})
# 2025-11-04 21:01:40.197 INFO: =============    Processing head Default     ===========
# 2025-11-04 21:01:40.265 INFO: Using isolated atom energies from training file
# 2025-11-04 21:01:40.274 INFO: Training set 1/1 [energy: 517, stress: 0, virials: 0, dipole components: 0, head: 517, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 517, charges: 0]
# 2025-11-04 21:01:40.276 INFO: Total Training set [energy: 517, stress: 0, virials: 0, dipole components: 0, head: 517, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 517, charges: 0]
# 2025-11-04 21:01:40.277 INFO: No validation set provided, splitting training data instead.
# 2025-11-04 21:01:40.277 INFO: Using random 1% of training set for validation with following indices: [5, 302, 291, 153, 461]
# 2025-11-04 21:01:40.279 INFO: Random Split Training set [energy: 512, stress: 0, virials: 0, dipole components: 0, head: 512, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 512, charges: 0]
# 2025-11-04 21:01:40.280 INFO: Random Split Validation set [energy: 5, stress: 0, virials: 0, dipole components: 0, head: 5, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 5, charges: 0]
# 2025-11-04 21:01:40.304 INFO: Test set 1/1 [energy: 116, stress: 0, virials: 0, dipole components: 0, head: 116, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 116, charges: 0]
# 2025-11-04 21:01:40.305 INFO: Total Test set [energy: 116, stress: 0, virials: 0, dipole components: 0, head: 116, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 116, charges: 0]
# 2025-11-04 21:01:40.306 INFO: Total number of configurations: train=512, valid=5, tests=[Fe13Si1B1_Default: 116],
# 2025-11-04 21:01:40.306 WARNING: Validation batch size (10) is larger than the number of validation data (5)
# 2025-11-04 21:01:40.307 INFO: Atomic Numbers used: [5, 14, 26]
# 2025-11-04 21:01:40.308 INFO: Atomic Energies used (z: eV) for head Default: {5: -0.27559471, 14: -0.81049333, 26: -3.283081}
# 2025-11-04 21:01:40.308 INFO: Processing datasets for head 'Default'
# 2025-11-04 21:01:40.551 INFO: Combining 1 list datasets for head 'Default'
# 2025-11-04 21:01:40.556 INFO: Head 'Default' training dataset size: 512
# 2025-11-04 21:01:40.559 INFO: Computing average number of neighbors
# 2025-11-04 21:01:40.673 INFO: Average number of neighbors: 17.92233009708738
# 2025-11-04 21:01:40.674 INFO: During training the following quantities will be reported: energy, forces
# 2025-11-04 21:01:40.675 INFO: ===========MODEL DETAILS===========
# 2025-11-04 21:01:40.741 INFO: Building model
# 2025-11-04 21:01:40.742 INFO: Message passing with 32 channels and max_L=0 (32x0e)
# 2025-11-04 21:01:40.742 INFO: 2 layers, each with correlation order: 3 (body order: 4) and spherical harmonics up to: l=3
# 2025-11-04 21:01:40.743 INFO: 8 radial and 5 basis functions
# 2025-11-04 21:01:40.743 INFO: Radial cutoff: 4.0 A (total receptive field for each atom: 8.0 A)
# 2025-11-04 21:01:40.743 INFO: Distance transform for radial basis functions: None
# 2025-11-04 21:01:40.743 INFO: Hidden irreps: 32x0e
# 2025-11-04 21:01:41.411 INFO: Total number of parameters: 58256
# 2025-11-04 21:01:41.412 INFO:
# 2025-11-04 21:01:41.412 INFO: ===========OPTIMIZER INFORMATION===========
# 2025-11-04 21:01:41.413 INFO: Using ADAM as parameter optimizer
# 2025-11-04 21:01:41.413 INFO: Batch size: 25
# 2025-11-04 21:01:41.413 INFO: Number of gradient updates: 512
# 2025-11-04 21:01:41.413 INFO: Learning rate: 0.0001, weight decay: 5e-07
# 2025-11-04 21:01:41.414 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2025-11-04 21:01:41.414 INFO: Using gradient clipping with tolerance=10.000
# 2025-11-04 21:01:41.415 INFO:
# 2025-11-04 21:01:41.415 INFO: ===========TRAINING===========
# 2025-11-04 21:01:41.415 INFO: Started training, reporting errors on validation set
# 2025-11-04 21:01:41.416 INFO: Loss metrics on validation set
# 2025-11-04 21:01:41.548 INFO: Initial: head: Default, loss=45.57401332, RMSE_E_per_atom= 1345.93 meV, RMSE_F= 1503.52 meV / A
# 2025-11-04 21:01:48.693 INFO: Epoch 0: head: Default, loss=45.43753697, RMSE_E_per_atom= 1342.49 meV, RMSE_F= 1501.28 meV / A
# 2025-11-04 21:01:55.321 INFO: Epoch 1: head: Default, loss=45.30940857, RMSE_E_per_atom= 1339.11 meV, RMSE_F= 1499.18 meV / A
# 2025-11-04 21:02:01.851 INFO: Epoch 2: head: Default, loss=45.18933925, RMSE_E_per_atom= 1336.30 meV, RMSE_F= 1497.20 meV / A
# 2025-11-04 21:02:08.526 INFO: Epoch 3: head: Default, loss=45.07997160, RMSE_E_per_atom= 1333.45 meV, RMSE_F= 1495.40 meV / A
# 2025-11-04 21:02:15.180 INFO: Epoch 4: head: Default, loss=44.97245074, RMSE_E_per_atom= 1330.72 meV, RMSE_F= 1493.62 meV / A
# 2025-11-04 21:02:21.969 INFO: Epoch 5: head: Default, loss=44.86991315, RMSE_E_per_atom= 1328.43 meV, RMSE_F= 1491.93 meV / A
# 2025-11-04 21:02:28.580 INFO: Epoch 6: head: Default, loss=44.77052241, RMSE_E_per_atom= 1325.97 meV, RMSE_F= 1490.28 meV / A
# 2025-11-04 21:02:35.244 INFO: Epoch 7: head: Default, loss=44.67952951, RMSE_E_per_atom= 1324.12 meV, RMSE_F= 1488.77 meV / A
# 2025-11-04 21:02:41.878 INFO: Epoch 8: head: Default, loss=44.58379865, RMSE_E_per_atom= 1322.22 meV, RMSE_F= 1487.18 meV / A
# 2025-11-04 21:02:48.551 INFO: Epoch 9: head: Default, loss=44.49241286, RMSE_E_per_atom= 1320.41 meV, RMSE_F= 1485.66 meV / A
# 2025-11-04 21:02:55.235 INFO: Epoch 10: head: Default, loss=44.40397561, RMSE_E_per_atom= 1318.87 meV, RMSE_F= 1484.18 meV / A
# 2025-11-04 21:03:01.866 INFO: Epoch 11: head: Default, loss=44.30665129, RMSE_E_per_atom= 1317.55 meV, RMSE_F= 1482.56 meV / A
# 2025-11-04 21:03:08.606 INFO: Epoch 12: head: Default, loss=44.20522989, RMSE_E_per_atom= 1316.22 meV, RMSE_F= 1480.86 meV / A
# 2025-11-04 21:03:15.259 INFO: Epoch 13: head: Default, loss=44.10002646, RMSE_E_per_atom= 1314.90 meV, RMSE_F= 1479.09 meV / A
# 2025-11-04 21:03:21.902 INFO: Epoch 14: head: Default, loss=43.99136000, RMSE_E_per_atom= 1313.82 meV, RMSE_F= 1477.26 meV / A
# 2025-11-04 21:03:28.550 INFO: Epoch 15: head: Default, loss=43.87454514, RMSE_E_per_atom= 1312.70 meV, RMSE_F= 1475.30 meV / A
# 2025-11-04 21:03:35.188 INFO: Epoch 16: head: Default, loss=43.74578085, RMSE_E_per_atom= 1311.83 meV, RMSE_F= 1473.12 meV / A
# 2025-11-04 21:03:41.937 INFO: Epoch 17: head: Default, loss=43.61870514, RMSE_E_per_atom= 1310.93 meV, RMSE_F= 1470.97 meV / A
# 2025-11-04 21:03:48.710 INFO: Epoch 18: head: Default, loss=43.47613318, RMSE_E_per_atom= 1310.00 meV, RMSE_F= 1468.55 meV / A
# 2025-11-04 21:03:55.329 INFO: Epoch 19: head: Default, loss=43.31640381, RMSE_E_per_atom= 1309.44 meV, RMSE_F= 1465.84 meV / A
# 2025-11-04 21:04:02.077 INFO: Epoch 20: head: Default, loss=43.15390994, RMSE_E_per_atom= 1308.73 meV, RMSE_F= 1463.07 meV / A
# 2025-11-04 21:04:08.718 INFO: Epoch 21: head: Default, loss=42.97234063, RMSE_E_per_atom= 1308.26 meV, RMSE_F= 1459.97 meV / A
# 2025-11-04 21:04:15.419 INFO: Epoch 22: head: Default, loss=42.78237286, RMSE_E_per_atom= 1307.70 meV, RMSE_F= 1456.71 meV / A
# 2025-11-04 21:04:22.042 INFO: Epoch 23: head: Default, loss=42.55657714, RMSE_E_per_atom= 1307.11 meV, RMSE_F= 1452.84 meV / A
# 2025-11-04 21:04:28.775 INFO: Epoch 24: head: Default, loss=42.31625752, RMSE_E_per_atom= 1306.82 meV, RMSE_F= 1448.70 meV / A
# 2025-11-04 21:04:28.785 INFO: Training complete
# 2025-11-04 21:04:28.786 INFO:
# 2025-11-04 21:04:28.786 INFO: ===========RESULTS===========
# 2025-11-04 21:04:28.852 INFO: Loading checkpoint: ./checkpoints/model_scaleshift_lr0.0001_highEweighted_25epochs_25batch_run-123_epoch-24.pt
# 2025-11-04 21:04:28.875 INFO: Loaded Stage one model from epoch 24 for evaluation
# 2025-11-04 21:04:28.877 INFO: Saving model to checkpoints/model_scaleshift_lr0.0001_highEweighted_25epochs_25batch_run-123.model
# 2025-11-04 21:04:29.059 INFO: Compiling model, saving metadata to model_scaleshift_lr0.0001_highEweighted_25epochs_25batch_compiled.model
# 2025-11-04 21:04:29.525 INFO: Computing metrics for training, validation, and test sets
# 2025-11-04 21:04:29.526 INFO: Skipping evaluation for heads: ['pt_head']
# 2025-11-04 21:04:29.526 INFO: Evaluating train_Default ...
# 2025-11-04 21:04:32.145 INFO: Evaluating valid_Default ...
# 2025-11-04 21:04:32.183 INFO: Error-table on TRAIN and VALID:
# +---------------+---------------------+------------------+-------------------+
# |  config_type  | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +---------------+---------------------+------------------+-------------------+
# | train_Default |         1829.3      |      37550.4     |       2931.79     |
# | valid_Default |         1306.8      |       1448.7     |         97.56     |
# +---------------+---------------------+------------------+-------------------+
# 2025-11-04 21:04:32.183 INFO: Evaluating Fe13Si1B1_Default ...
# 2025-11-04 21:04:33.084 INFO: Error-table on TEST:
# +-------------------+---------------------+------------------+-------------------+
# |    config_type    | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------------+---------------------+------------------+-------------------+
# | Fe13Si1B1_Default |         7803.9      |       2460.2     |         97.89     |
# +-------------------+---------------------+------------------+-------------------+
# 2025-11-04 21:04:33.239 INFO: Done

# %%
#reading the information on the results file
results = f'results/{model_name}_run-123_train.txt' #reading the file where the training results is stored
data = [] #where the data from the 'results' file will be stored
with open(results, 'r') as f:
    for line in f:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError:
            continue

# %%
results
# Out:
# 'results/model_scaleshift_lr0.0001_highEweighted_25epochs_25batch_run-123_train.txt'

# %%
#saving the data in a dataframe to be able to work with it in an easier way
df = pd.DataFrame(data)
#separating the training and validation results
train_df = df[df['mode']=='opt'].copy()
val_df = df[df['mode']=='eval'].copy().dropna()
#train_df = train_df.groupby('epoch', as_index=False)['loss'].last()
train_df = train_df.groupby('epoch', as_index=False)['loss'].mean()
train_df['epoch'] += 1
val_df['epoch'] += 1

#plotting the dataframe
import functions as f
f.plot_mae(val_df, 'epoch', ['mae_e','mae_f'])

# %%
#plotting the validation and loss error
f.plot_loss([(train_df, 'train'),(val_df,'val')],'epoch','loss',model_name)

# %%
#the model can be evaluated using this
from mace.cli.eval_configs import main as mace_eval_configs_main
import sys

def eval_mace(model, configs, output, device=device):
    sys.argv=['program', '--configs', configs, '--model', model, '--output', output, '--device', device]
    mace_eval_configs_main()

# %%
#evaluating the set on both the training and test datasets
'''eval_mace(model=f'{model_name}.model',
          configs='train_01.xyz',
          output=f'test_res/{model_name}_train.xyz')'''

eval_mace(model=f'{model_name}.model',
          configs='test_01.xyz',
          output=f'test_res/{model_name}_test.xyz')
# Out:
# 2025-11-04 21:05:22.696 INFO: Using CPU

# %%
from ase.io import read

#importing data from the evaluation of the test set
#read the configurations with the mace predictions
res_list = read(f'test_res/{model_name}_test.xyz', index=':')
#extracting the reference and mace energies
res = [(a.info['REF_energy'], a.info['MACE_energy']) for a in res_list]
df_res = pd.DataFrame(res, columns=['REF_energy', 'MACE_energy'])
df_res
# Out:
#      REF_energy  MACE_energy
# 0   -107.243922   -91.890805
# 1   -106.697872   -92.048745
# 2   -631.906714   -91.943720
# 3   -111.647618   -92.536185
# 4   -112.027482   -92.628215
# ..          ...          ...
# 111 -106.479300   -91.959213
# 112 -102.204540   -91.803061
# 113 -101.649356   -92.002574
# 114  -98.841753   -91.888559
# 115 -110.279499   -92.499049
#
# [116 rows x 2 columns]

# %%
#saving to an excel file so that we can keep a register of how different the resuls are for the different models
df_res.to_excel(f'test_res/{model_name}_test.xlsx')

# %%
f.plot_energy_comparison(df_res, 'REF_energy', 'MACE_energy')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

rmse = np.sqrt(mean_squared_error(df_res['REF_energy'],df_res['MACE_energy']))
mae =  mean_absolute_error(df_res['REF_energy'],df_res['MACE_energy'])
r2 = r2_score(df_res['REF_energy'],df_res['MACE_energy'])

print(rmse, mae, r2)
# Out:
# 117.05844384475547 35.52744911816722 -0.1009874018350172
